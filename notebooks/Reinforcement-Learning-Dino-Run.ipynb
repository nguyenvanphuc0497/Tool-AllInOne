# %%
# %pip install opencv-python
# %pip install keras
# %pip install tensorflow
# %pip install selenium
# Out:
# Requirement already satisfied: opencv-python in d:\dinoruntutorial\.venv\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in d:\dinoruntutorial\.venv\lib\site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: keras in d:\dinoruntutorial\.venv\lib\site-packages (2.11.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in d:\dinoruntutorial\.venv\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.21)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.30.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: setuptools in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: h5py>=2.9.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.24.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: packaging in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\dinoruntutorial\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\dinoruntutorial\.venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\dinoruntutorial\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\dinoruntutorial\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\dinoruntutorial\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\dinoruntutorial\.venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\dinoruntutorial\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\dinoruntutorial\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\dinoruntutorial\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\dinoruntutorial\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\dinoruntutorial\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\dinoruntutorial\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\dinoruntutorial\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: selenium in d:\dinoruntutorial\.venv\lib\site-packages (4.8.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: certifi>=2021.10.8 in d:\dinoruntutorial\.venv\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]~=1.26 in d:\dinoruntutorial\.venv\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio-websocket~=0.9 in d:\dinoruntutorial\.venv\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in d:\dinoruntutorial\.venv\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: idna in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sniffio in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sortedcontainers in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in d:\dinoruntutorial\.venv\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in d:\dinoruntutorial\.venv\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\dinoruntutorial\.venv\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\dinoruntutorial\.venv\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in d:\dinoruntutorial\.venv\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "../chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
# %pip install webdriver-manager

# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.common.by import By
# import time

'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        # chrome_options.add_argument("start-maximized")
        # self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        try:
            self._driver.get('chrome://dino')
        except:
            print("continue with ")
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        # self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
        self._driver.find_element(By.TAG_NAME,"body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
game = Game()
dino = DinoAgent(game)
game_state = Game_sate(dino,game)    

# game_state.get_state([ACTIONS])
# Out:
# continue with

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
# init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(learning_rate=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(learning_rate=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(learning_rate=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
# Test Game class
# a =Game()
# a.press_up()
# while a.get_crashed()!=True:
#     time.sleep(1)
#     print(a.get_score())

# %%
playGame(observe=False);
# Out:
# continue with
# Now we build the model
# We finish building the model
# 1/1 [==============================] - 0s 93ms/step
# fps: 4.1702790225510835
# TIMESTEP 1 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 11.172446492548247
# TIMESTEP 2 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 10.768044280821742
# TIMESTEP 3 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 9.616654820589247
# TIMESTEP 4 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 15.424828717375394
# TIMESTEP 5 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 11.103797361119936
# TIMESTEP 6 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 10.440916264643358
# TIMESTEP 7 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 10.596198882856573
# TIMESTEP 8 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 10.888922350009086
# TIMESTEP 9 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 32.00879147715132
# TIMESTEP 10 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 7.954544420084812
# TIMESTEP 11 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 10.55383221780484
# TIMESTEP 12 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 9.252760294990326
# TIMESTEP 13 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 32.18415923635303
# TIMESTEP 14 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 10.261595447450444
# TIMESTEP 15 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 11.012082482238593
# TIMESTEP 16 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 9.16437209810455
# TIMESTEP 17 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 29ms/step
# fps: 9.388460238477363
# TIMESTEP 18 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 31.754822688592107
# TIMESTEP 19 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 29ms/step
# fps: 10.230608620992449
# TIMESTEP 20 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 31ms/step
# fps: 9.352077754415381
# TIMESTEP 21 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.49607239112428
# TIMESTEP 22 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 10.175804980300061
# TIMESTEP 23 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 11.289486788166547
# TIMESTEP 24 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 7.890288913386183
# TIMESTEP 25 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# fps: 9.367701416667225
# TIMESTEP 26 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 77ms/step
# fps: 5.828312093635317
# TIMESTEP 27 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 33ms/step
# fps: 9.26823792498442
# TIMESTEP 28 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 34ms/step
# fps: 8.460266456889856
# TIMESTEP 29 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# fps: 7.740953393388738
# TIMESTEP 30 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# fps: 7.565892815267781
# TIMESTEP 31 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 9.59307628618871
# TIMESTEP 32 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.7796122293727
# TIMESTEP 33 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 9.93131927327144
# TIMESTEP 34 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 8.425071710362449
# TIMESTEP 35 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# fps: 4.633868093479358
# TIMESTEP 36 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 7.318318548865516
# TIMESTEP 37 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 30ms/step
# fps: 2.796275369826282
# TIMESTEP 38 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 6.518593117896546
# TIMESTEP 39 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 8.794786415828629
# TIMESTEP 40 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 7.213016194575668
# TIMESTEP 41 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 5.8244029517056735
# TIMESTEP 42 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 6.421605897528152
# TIMESTEP 43 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 5.92449290920391
# TIMESTEP 44 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 5.031307241366488
# TIMESTEP 45 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 16.710174778787504
# TIMESTEP 46 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 8.020805923568828
# TIMESTEP 47 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 29ms/step
# fps: 6.661474248613485
# TIMESTEP 48 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 52ms/step
# fps: 6.820483383391034
# TIMESTEP 49 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 11.265774029357651
# TIMESTEP 50 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.666069911859994
# TIMESTEP 51 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 16.709975060357124
# TIMESTEP 52 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.336169782818164
# TIMESTEP 53 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 15.914461227912412
# TIMESTEP 54 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.230708438625078
# TIMESTEP 55 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 11.265320154705629
# TIMESTEP 56 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.780083222173388
# TIMESTEP 57 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 29ms/step
# fps: 11.140131313345941
# TIMESTEP 58 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 33.42021641089385
# TIMESTEP 59 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 7.872591141067584
# TIMESTEP 60 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.86643850699635
# TIMESTEP 61 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 10.721992295244986
# TIMESTEP 62 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 15.665820061553172
# TIMESTEP 63 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 10.897834361805781
# TIMESTEP 64 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 9.283233181722608
# TIMESTEP 65 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 8.643273407684001
# TIMESTEP 66 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 7.894640353106149
# TIMESTEP 67 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.78063738404715
# TIMESTEP 68 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 30ms/step
# fps: 8.951820754596174
# TIMESTEP 69 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 11.658325203116444
# TIMESTEP 70 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 11.01763639706848
# TIMESTEP 71 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 8.068063824262069
# TIMESTEP 72 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 8.003480517497996
# TIMESTEP 73 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 9.324778458077109
# TIMESTEP 74 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.780803643719493
# TIMESTEP 75 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 10.443906046518578
# TIMESTEP 76 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 28ms/step
# fps: 7.426714757976411
# TIMESTEP 77 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 7.924621416088045
# TIMESTEP 78 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 8.18330523818443
# TIMESTEP 79 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.497096864613782
# TIMESTEP 80 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.780166342822483
# TIMESTEP 81 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 9.198620087681014
# TIMESTEP 82 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 30ms/step
# fps: 8.794786415828629
# TIMESTEP 83 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 11.017723221439136
# TIMESTEP 84 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.443880041035447
# TIMESTEP 85 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 9.73425145225712
# TIMESTEP 86 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 9.279659460739088
# TIMESTEP 87 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 11.268891623365807
# TIMESTEP 88 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 9.42068132149507
# TIMESTEP 89 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 10.77698096821355
# TIMESTEP 90 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 24ms/step
# fps: 10.406591852482242
# TIMESTEP 91 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 10.595797355537254
# TIMESTEP 92 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.83413149832876
# TIMESTEP 93 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# fps: 7.286686170545437
# TIMESTEP 94 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 10.613090553920664
# TIMESTEP 95 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 22ms/step
# fps: 10.245177616617774
# TIMESTEP 96 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 11.07146835463086
# TIMESTEP 97 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 26ms/step
# fps: 10.6136813950134
# TIMESTEP 98 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 25ms/step
# fps: 10.88977048499325
# TIMESTEP 99 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 23ms/step
# fps: 10.690319259021374
# TIMESTEP 100 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 27ms/step
# fps: 10.287494266744172
# TIMESTEP 101 / STATE explore / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# fps: 16.683454982995563
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# TIMESTEP 102 / STATE explore / EPSILON 0.099999001 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0765448 / Loss  1.3157293796539307
# 1/1 [==============================] - 0s 27ms/step
# fps: 0.33898063448793103
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# TIMESTEP 103 / STATE explore / EPSILON 0.099998002 / ACTION 0 / REWARD 0.1 / Q_MAX  4.0974383 / Loss  1.280806064605713
# 1/1 [==============================] - 0s 27ms/step
# fps: 0.4251605868412706
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# TIMESTEP 104 / STATE explore / EPSILON 0.099997003 / ACTION 0 / REWARD -1 / Q_MAX  2.911304 / Loss  0.8290640115737915
# 1/1 [==============================] - 0s 27ms/step
# fps: 0.4126565194364941
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# TIMESTEP 105 / STATE explore / EPSILON 0.099996004 / ACTION 0 / REWARD 0.1 / Q_MAX  3.3917935 / Loss  1.132089376449585
# 1/1 [==============================] - 0s 24ms/step
# fps: 0.4098019395104267
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# TIMESTEP 106 / STATE explore / EPSILON 0.099995005 / ACTION 0 / REWARD -1 / Q_MAX  5.61092 / Loss  0.16671089828014374
# 1/1 [==============================] - 0s 23ms/step
# fps: 0.41554390100270194
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# TIMESTEP 107 / STATE explore / EPSILON 0.099994006 / ACTION 1 / REWARD 0.1 / Q_MAX  2.7569013 / Loss  0.9119633436203003
# 1/1 [==============================] - 0s 26ms/step
# fps: 0.41927769906200163
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# TIMESTEP 108 / STATE explore / EPSILON 0.099993007 / ACTION 0 / REWARD -1 / Q_MAX  3.3797154 / Loss  1.8757011890411377
# 1/1 [==============================] - 0s 27ms/step
# fps: 0.21445480122544316
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# TIMESTEP 109 / STATE explore / EPSILON 0.099992008 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8851292 / Loss  0.5738340020179749
# 1/1 [==============================] - 0s 28ms/step
# fps: 0.430864111672212
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# TIMESTEP 110 / STATE explore / EPSILON 0.09999100899999999 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6483858 / Loss  0.8398132920265198
# 1/1 [==============================] - 0s 23ms/step
# fps: 0.4078347208659238
# 1/1 [==============================] - 0s 69ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 playGame(observe=False);
#
# Cell In[17], line 8, in playGame(observe)
#       6 model = buildmodel()
#       7 try:
# ----> 8     trainNetwork(model,game_state,observe=observe)
#       9 except StopIteration:
#      10     game.end()
#
# Cell In[22], line 101, in trainNetwork(model, game_state, observe)
#      98 inputs[i:i + 1] = state_t
#     100 targets[i] = model.predict(state_t)  # predicted q values
# --> 101 Q_sa = model.predict(state_t1)      #predict q values for next step
#     103 if terminal:
#     104     targets[i, action_t] = reward_t # if terminated, only equals reward
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\engine\training.py:2317, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2308     except ValueError:
#    2309         warnings.warn(
#    2310             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2311             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2314             stacklevel=2,
#    2315         )
# -> 2317 data_handler = data_adapter.get_data_handler(
#    2318     x=x,
#    2319     batch_size=batch_size,
#    2320     steps_per_epoch=steps,
#    2321     initial_epoch=0,
#    2322     epochs=1,
#    2323     max_queue_size=max_queue_size,
#    2324     workers=workers,
#    2325     use_multiprocessing=use_multiprocessing,
#    2326     model=self,
#    2327     steps_per_execution=self._steps_per_execution,
#    2328 )
#    2330 # Container that configures and calls `tf.keras.Callback`s.
#    2331 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\engine\data_adapter.py:1579, in get_data_handler(*args, **kwargs)
#    1577 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579 return DataHandler(*args, **kwargs)
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\engine\data_adapter.py:1259, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1256     self._steps_per_execution = steps_per_execution
#    1258 adapter_cls = select_data_adapter(x, y)
# -> 1259 self._adapter = adapter_cls(
#    1260     x,
#    1261     y,
#    1262     batch_size=batch_size,
#    1263     steps=steps_per_epoch,
#    1264     epochs=epochs - initial_epoch,
#    1265     sample_weights=sample_weight,
#    1266     shuffle=shuffle,
#    1267     max_queue_size=max_queue_size,
#    1268     workers=workers,
#    1269     use_multiprocessing=use_multiprocessing,
#    1270     distribution_strategy=tf.distribute.get_strategy(),
#    1271     model=model,
#    1272 )
#    1274 strategy = tf.distribute.get_strategy()
#    1276 self._current_step = 0
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\engine\data_adapter.py:347, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     343     return flat_dataset
#     345 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 347 dataset = self.slice_inputs(indices_dataset, inputs)
#     349 if shuffle == "batch":
#     351     def shuffle_batch(*batch):
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\keras\engine\data_adapter.py:388, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     383 def grab_batch(i, data):
#     384     return tf.nest.map_structure(
#     385         lambda d: tf.gather(d, i, axis=0), data
#     386     )
# --> 388 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     390 # Default optimizations are disabled to avoid the overhead of
#     391 # (unnecessary) input pipeline graph serialization and deserialization
#     392 options = tf.data.Options()
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2296, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2294   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2295 else:
# -> 2296   return ParallelMapDataset(
#    2297       self,
#    2298       map_func,
#    2299       num_parallel_calls,
#    2300       deterministic,
#    2301       preserve_cardinality=True,
#    2302       name=name)
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5555, in ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5552 self._num_parallel_calls = ops.convert_to_tensor(
#    5553     num_parallel_calls, dtype=dtypes.int64, name="num_parallel_calls")
#    5554 self._name = name
# -> 5555 variant_tensor = gen_dataset_ops.parallel_map_dataset_v2(
#    5556     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5557     self._map_func.function.captured_inputs,
#    5558     f=self._map_func.function,
#    5559     num_parallel_calls=self._num_parallel_calls,
#    5560     deterministic=self._deterministic,
#    5561     use_inter_op_parallelism=self._use_inter_op_parallelism,
#    5562     preserve_cardinality=self._preserve_cardinality,
#    5563     **self._common_args)
#    5564 super(ParallelMapDataset, self).__init__(input_dataset, variant_tensor)
#
# File d:\DinoRunTutorial\.venv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6184, in parallel_map_dataset_v2(input_dataset, other_arguments, num_parallel_calls, f, output_types, output_shapes, use_inter_op_parallelism, deterministic, preserve_cardinality, metadata, name)
#    6182 if tld.is_eager:
#    6183   try:
# -> 6184     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6185       _ctx, "ParallelMapDatasetV2", name, input_dataset, other_arguments,
#    6186       num_parallel_calls, "f", f, "output_types", output_types,
#    6187       "output_shapes", output_shapes, "use_inter_op_parallelism",
#    6188       use_inter_op_parallelism, "deterministic", deterministic,
#    6189       "preserve_cardinality", preserve_cardinality, "metadata", metadata)
#    6190     return _result
#    6191   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
